# %%
import requests
import time

# %%
url = "http://localhost:11434/api/generate"

# %%
payload = {
    "model": "phi3:mini",
    "prompt": "Explain quantum mechanics in simple terms",
    "stream": False
}

# %%
start = time.time()
response = requests.post(url = url, json = payload)
end = time.time()

# %%
response.json()["response"]
# Out:
# 'Quantum mechanics is a branch of physics that studies how things work at a very, very small scale—the world of atoms and subatomic particles. Here\'s a simple way to understand it:\n\n\nImagine you\'re at a party where everyone is moving in their unique way, sometimes they seem to be in multiple places at once, and they can switch between behaving like particles and waves. In the quantum world, particles such as electrons or photons can behave like this. They do not have definite positions or speeds but exist in probabilities of being in different places or having different speeds.\n\n\nThese tiny particles follow different rules than the stuff we see around us every day. For example, they can be linked in a way that changing the state of one instantly affects the state of another, no matter the distance between them, which seems to defy how we understand the world. This is called "quantum entanglement."\n\n\nQuantum mechanics is the theory that explains these weird behaviors, and it\'s a crucial part of understanding the world at a microscopic level. It\'s also important for developing new technologies like quantum computers and lasers. But don\'t worry if this seems overwhelming—it\'s a complex field even for many scientists, and it\'s okay not to grasp all of it right away. It\'s enough for now to appreciate that the quantum world is full of surprises!'
